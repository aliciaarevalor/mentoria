# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
temp = pd.read_csv('C:/Users/VICTUS/Documents/UN/mujeres-digitales-mentoria/datos-siata-68/estacion_data_temperatura_68__20170101_20170131.csv')
print(temp)
# Out:
#        codigo           fecha_hora  temperatura  calidad
# 0          68  2017-01-01 00:00:03         19.1        1
# 1          68  2017-01-01 00:01:03         19.1        1
# 2          68  2017-01-01 00:02:03         19.1        1
# 3          68  2017-01-01 00:03:03         19.1        1
# 4          68  2017-01-01 00:04:03         19.1        1
# ...       ...                  ...          ...      ...
# 44529      68  2017-01-31 23:55:42         20.1        1
# 44530      68  2017-01-31 23:56:42         20.2        1
# 44531      68  2017-01-31 23:57:42         20.2        1
# 44532      68  2017-01-31 23:58:42         20.2        1
# 44533      68  2017-01-31 23:59:42         20.2        1
#
# [44534 rows x 4 columns]

# %%
temp.plot(x = 'fecha_hora', y = 'temperatura')
plt.show()
